# %%
import pandas as pd 

df_leads = pd.read_excel("D:/whaw/case-study-real-estate/data/Case_Study_Data___Data_Engineering__1_.xlsx", sheet_name="DE LEADS")
print(f"df_leads.shape {df_leads.shape}")
df_leads.head()
# Out:
# df_leads.shape (55924, 25)
#        id date_of_last_request  buyer  seller  best_time_to_call  budget  \
# 0    9815  2018-09-07 00:00:00   True   False  All day , any day     NaN
# 1   90225  2022-05-04 19:59:00   True   False                NaN     NaN
# 2  198759  2023-03-22 05:23:00   True   False                NaN     NaN
# 3  164130  2022-12-14 00:59:00   True   False                NaN     NaN
# 4  395907  2024-01-20 17:57:00   True   False                NaN     NaN
#
#            created_at          updated_at  user_id                   location  \
# 0 2018-09-07 15:58:00 2024-01-24 15:07:00   2942.0                   Coast 82
# 1 2022-05-04 19:59:00 2024-01-10 13:10:00   1494.0   The Waterway North Coast
# 2 2023-03-22 05:23:00 2024-02-07 15:45:00   4043.0               Silversands
# 3 2022-12-14 00:51:00 2024-01-15 14:38:00   3805.0                  Fouka Bay
# 4 2024-01-20 17:57:00 2024-01-22 14:58:00   4003.0               Golden Eagle
#
#    ... compound_id developer_id  meeting_flag  do_not_call  lead_type_id  \
# 0  ...       170.0          NaN           NaN        False             1
# 1  ...         NaN          NaN           NaN        False             1
# 2  ...         NaN          NaN           NaN        False             1
# 3  ...         NaN          NaN           NaN        False             1
# 4  ...         NaN          NaN           NaN        False             1
#
#    customer_id  method_of_contact     lead_source  \
# 0        22785       form adwords          google
# 1       172065       generic form          google
# 2       192904           whatsapp  google website
# 3       112217           facebook        facebook
# 4       383990           facebook        facebook
#
#                                             campaign  lead_type
# 0                                         google_cpc    Primary
# 1                                       dev_-_equity    Primary
# 2                                                NaN    Primary
# 3                                             (none)    Primary
# 4  madinet nasr for housing and development - lea...    Primary
#
# [5 rows x 25 columns]

# %%
df_leads["location"].unique()
# Out:
# array(['Coast 82', ' The Waterway North Coast', 'Silversands ', ...,
#        'zoya - sahel', 'pyramid hills', ' The Waterway North Coast '],
#       shape=(3085,), dtype=object)

# %%
df_leads["best_time_to_call"].dropna().tail(20)
# Out:
# 55286                                                 8pm
# 55315                                        8 am to 4 pm
# 55332                                             Any time
# 55348                                  10-01-2024, 8:17 PM
# 55353                                             any time
# 55358                                             Anytime
# 55375                                             Any time
# 55405                                  01-02-2024, 7:19 AM
# 55443                                             Day time
# 55461                                           After 8 pm
# 55516                               After 6 pm Dubai time
# 55519                                             12:30:00
# 55574                                              10:30AM
# 55582    10/25/2018 @ 5pm Egypt time will be 11 am USA ...
# 55593                                                  6pm
# 55653                                             10:00:00
# 55657                                        After 7:30 pm
# 55679                                                    3
# 55726                                           Afternoon
# 55743                                             Whatsapp
# Name: best_time_to_call, dtype: object

# %%
df_leads[df_leads["id"].duplicated(keep=False)].sort_values(by="id", ascending=True).reset_index(drop=True)
# Out:
#          id date_of_last_request  buyer  seller             best_time_to_call  \
# 0     10809  2023-02-23 14:26:00   True   False                           NaN
# 1     10809  2023-02-23 14:26:00   True   False                           NaN
# 2     14874  2019-05-11 00:00:00   True   False                           NaN
# 3     14874  2019-05-11 00:00:00   True   False                           NaN
# 4     14902  2022-01-28 12:16:00   True   False  Any day around 1:00 uk time
# ..      ...                  ...    ...     ...                           ...
# 138  361917  2023-12-03 20:22:00   True   False                           NaN
# 139  371499  2023-12-16 11:11:00   True   False                           NaN
# 140  371499  2023-12-16 11:11:00   True   False                           NaN
# 141  398324  2024-01-23 14:41:00   True   False                           NaN
# 142  398324  2024-01-23 14:41:00   True   False                           NaN
#
#      budget          created_at          updated_at  user_id  \
# 0       NaN 2018-10-26 21:53:00 2023-12-10 14:22:00     66.0
# 1       NaN 2018-10-26 21:53:00 2023-12-10 14:22:00     66.0
# 2       NaN 2019-05-11 21:46:00 2021-08-22 10:40:00      2.0
# 3       NaN 2019-05-11 21:46:00 2021-08-22 10:40:00      2.0
# 4       NaN 2019-05-13 22:51:00 2023-05-25 13:58:00    235.0
# ..      ...                 ...                 ...      ...
# 138     NaN 2023-12-03 20:23:00 2023-12-07 21:17:00   3908.0
# 139     NaN 2023-12-16 11:11:00 2023-12-27 13:00:00   1327.0
# 140     NaN 2023-12-16 11:11:00 2023-12-27 13:00:00   1327.0
# 141     NaN 2024-01-23 14:41:00 2024-02-07 10:21:00    671.0
# 142     NaN 2024-01-23 14:41:00 2024-02-07 10:21:00    671.0
#
#              location  ... compound_id developer_id  meeting_flag  \
# 0              Solana  ...         NaN          NaN           NaN
# 1              Solana  ...         NaN          NaN           NaN
# 2                 Zed  ...       274.0          NaN           NaN
# 3                 Zed  ...       274.0          NaN           NaN
# 4    Badya-Palm Hills  ...       269.0          NaN           NaN
# ..                ...  ...         ...          ...           ...
# 138               NaN  ...         NaN          NaN           NaN
# 139    Al Maqsad Park  ...         NaN          NaN           NaN
# 140    Al Maqsad Park  ...         NaN          NaN           NaN
# 141         New Cairo  ...         NaN          NaN           NaN
# 142         New Cairo  ...         NaN          NaN           NaN
#
#      do_not_call  lead_type_id  customer_id  method_of_contact  \
# 0          False             1        25487           personal
# 1          False             1        25487           personal
# 2          False             1        22575              phone
# 3          False             1        22575              phone
# 4          False             1        50163           whatsapp
# ..           ...           ...          ...                ...
# 138        False             1       351914           personal
# 139        False             1       361059           whatsapp
# 140        False             1       361059           whatsapp
# 141        False             4       386227     ambassador app
# 142        False             4       386227     ambassador app
#
#         lead_source        campaign  lead_type
# 0          personal             NaN    Primary
# 1          personal             NaN    Primary
# 2             phone             NaN    Primary
# 3             phone             NaN    Primary
# 4           website             NaN    Primary
# ..              ...             ...        ...
# 138        personal             NaN    Primary
# 139         website             NaN    Primary
# 140         website             NaN    Primary
# 141  ambassador app  ambassador app   Nawy Now
# 142  ambassador app  ambassador app   Nawy Now
#
# [143 rows x 25 columns]

# %%
df_leads[df_leads.duplicated(keep=False)].sort_values(by="id", ascending=True).reset_index(drop=True)
# Out:
#          id date_of_last_request  buyer  seller             best_time_to_call  \
# 0     10809  2023-02-23 14:26:00   True   False                           NaN
# 1     10809  2023-02-23 14:26:00   True   False                           NaN
# 2     14874  2019-05-11 00:00:00   True   False                           NaN
# 3     14874  2019-05-11 00:00:00   True   False                           NaN
# 4     14902  2022-01-28 12:16:00   True   False  Any day around 1:00 uk time
# ..      ...                  ...    ...     ...                           ...
# 138  361917  2023-12-03 20:22:00   True   False                           NaN
# 139  371499  2023-12-16 11:11:00   True   False                           NaN
# 140  371499  2023-12-16 11:11:00   True   False                           NaN
# 141  398324  2024-01-23 14:41:00   True   False                           NaN
# 142  398324  2024-01-23 14:41:00   True   False                           NaN
#
#      budget          created_at          updated_at  user_id  \
# 0       NaN 2018-10-26 21:53:00 2023-12-10 14:22:00     66.0
# 1       NaN 2018-10-26 21:53:00 2023-12-10 14:22:00     66.0
# 2       NaN 2019-05-11 21:46:00 2021-08-22 10:40:00      2.0
# 3       NaN 2019-05-11 21:46:00 2021-08-22 10:40:00      2.0
# 4       NaN 2019-05-13 22:51:00 2023-05-25 13:58:00    235.0
# ..      ...                 ...                 ...      ...
# 138     NaN 2023-12-03 20:23:00 2023-12-07 21:17:00   3908.0
# 139     NaN 2023-12-16 11:11:00 2023-12-27 13:00:00   1327.0
# 140     NaN 2023-12-16 11:11:00 2023-12-27 13:00:00   1327.0
# 141     NaN 2024-01-23 14:41:00 2024-02-07 10:21:00    671.0
# 142     NaN 2024-01-23 14:41:00 2024-02-07 10:21:00    671.0
#
#              location  ... compound_id developer_id  meeting_flag  \
# 0              Solana  ...         NaN          NaN           NaN
# 1              Solana  ...         NaN          NaN           NaN
# 2                 Zed  ...       274.0          NaN           NaN
# 3                 Zed  ...       274.0          NaN           NaN
# 4    Badya-Palm Hills  ...       269.0          NaN           NaN
# ..                ...  ...         ...          ...           ...
# 138               NaN  ...         NaN          NaN           NaN
# 139    Al Maqsad Park  ...         NaN          NaN           NaN
# 140    Al Maqsad Park  ...         NaN          NaN           NaN
# 141         New Cairo  ...         NaN          NaN           NaN
# 142         New Cairo  ...         NaN          NaN           NaN
#
#      do_not_call  lead_type_id  customer_id  method_of_contact  \
# 0          False             1        25487           personal
# 1          False             1        25487           personal
# 2          False             1        22575              phone
# 3          False             1        22575              phone
# 4          False             1        50163           whatsapp
# ..           ...           ...          ...                ...
# 138        False             1       351914           personal
# 139        False             1       361059           whatsapp
# 140        False             1       361059           whatsapp
# 141        False             4       386227     ambassador app
# 142        False             4       386227     ambassador app
#
#         lead_source        campaign  lead_type
# 0          personal             NaN    Primary
# 1          personal             NaN    Primary
# 2             phone             NaN    Primary
# 3             phone             NaN    Primary
# 4           website             NaN    Primary
# ..              ...             ...        ...
# 138        personal             NaN    Primary
# 139         website             NaN    Primary
# 140         website             NaN    Primary
# 141  ambassador app  ambassador app   Nawy Now
# 142  ambassador app  ambassador app   Nawy Now
#
# [143 rows x 25 columns]
